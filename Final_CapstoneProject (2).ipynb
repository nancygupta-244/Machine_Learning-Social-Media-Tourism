# %% [markdown]
# *   **UserID** - Unique ID of user
#
# *   **Buy_ticket** - Buy ticket in next month
# *   **Yearly_avg_view_on_travel_page** - Average yearly views on any travel related page by user
# *  **preferred_device** - Through which device user preferred to do login
# *   **total_likes_on_outstation_checkin_given** - Total number of likes given by a user on out of station checkings in last year
# *   **yearly_avg_Outstation_checkins** - Average number of out of station check-in done by user
# *   **member_in_family** -Total number of relationship mentioned by user in the
# account
# *   **preferred_location_type** - Preferred type of the location for travelling of user
# *  **Yearly_avg_comment_on_travel_page**  - Average yearly comments on any travel related page by user
# *   **total_likes_on_outofstation_checkin_received** -
# Total number of likes received by a user on out of station
# checkings in last year
# *   **week_since_last_outstation_checkin** - Number of weeks since last out of station check-in update by user
# *   **following_company_page** - Weather the customer is following company page (Yes or No)
#
# *   **montly_avg_comment_on_company_page** - Average monthly comments on company page by user
#
# *   **working_flag** - Weather the customer is working or not
#
# *   **travelling_network_rating**- Does user have close friends who also like travelling. 1 is
# highs and 4 is lowest
#
#
# *   **Adult_flag** - Weather the customer is adult or not
#
# *   **Daily_Avg_mins_spend_on_traveling_page** - Average time spend on the company page by user on daily basis

# %% [markdown]
# ###Upload Required Libraries and import the dataset

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib
from matplotlib import pyplot as plt
import os
import matplotlib.style
plt.style.use('classic')
# %matplotlib inline

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
df =pd.read_csv("/content/drive/MyDrive/Capstone_Project/Social_Media_Data_for_DSBA.csv")

# %% [markdown]
# #EDA

# %%
df.head()
# Out:
#     UserID Taken_product  Yearly_avg_view_on_travel_page preferred_device  \
# 0  1000001           Yes                           307.0  iOS and Android
# 1  1000002            No                           367.0              iOS
# 2  1000003           Yes                           277.0  iOS and Android
# 3  1000004            No                           247.0              iOS
# 4  1000005            No                           202.0  iOS and Android
#
#    total_likes_on_outstation_checkin_given yearly_avg_Outstation_checkins  \
# 0                                  38570.0                              1
# 1                                   9765.0                              1
# 2                                  48055.0                              1
# 3                                  48720.0                              1
# 4                                  20685.0                              1
#
# ...

# %%
df.tail()
# Out:
#         UserID Taken_product  Yearly_avg_view_on_travel_page preferred_device  \
# 11755  1011756            No                           279.0           Laptop
# 11756  1011757            No                           305.0              Tab
# 11757  1011758            No                           214.0              Tab
# 11758  1011759            No                           382.0           Laptop
# 11759  1011760            No                           270.0              Tab
#
#        total_likes_on_outstation_checkin_given yearly_avg_Outstation_checkins  \
# 11755                                  30987.0                             23
# 11756                                  21510.0                              6
# 11757                                   5478.0                              4
# 11758                                  35851.0                              2
# 11759                                  22025.0                              8
#
# ...

# %%
print("no. of rows: ",df.shape[0], "\n""no. of columns: ",df.shape[1])
# Out:
# no. of rows:  11760
# no. of columns:  17

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11760 entries, 0 to 11759
# Data columns (total 17 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   UserID                                        11760 non-null  int64
#  1   Taken_product                                 11760 non-null  object
#  2   Yearly_avg_view_on_travel_page                11179 non-null  float64
#  3   preferred_device                              11707 non-null  object
#  4   total_likes_on_outstation_checkin_given       11379 non-null  float64
#  5   yearly_avg_Outstation_checkins                11685 non-null  object
#  6   member_in_family                              11760 non-null  object
#  7   preferred_location_type                       11729 non-null  object
#  8   Yearly_avg_comment_on_travel_page             11554 non-null  float64
# ...

# %% [markdown]
# #Treating Duplicates

# %%
df=df.drop('UserID', axis=1) #Dropping the 'UserID' column

# %%
dups = df.duplicated()
print('Number of duplicate rows = %d' % (dups.sum()))
# Out:
# Number of duplicate rows = 996

# %%
df.drop_duplicates(inplace=True)

# %%
dups = df.duplicated()
print('Number of duplicate rows = %d' % (dups.sum()))
# Out:
# Number of duplicate rows = 0

# %% [markdown]
# #Checking each categorical variable and treating them

# %%
df["Taken_product"].value_counts()
# Out:
# Taken_product
# No     9029
# Yes    1735
# Name: count, dtype: int64

# %%
df["Taken_product"]=df["Taken_product"].replace({"Yes":1, "No":0})

# %%
df['Taken_product']=df['Taken_product'].astype("object")

# %%
df["Taken_product"].value_counts()
# Out:
# Taken_product
# 0    9029
# 1    1735
# Name: count, dtype: int64

# %%
df["preferred_device"].value_counts()
# Out:
# preferred_device
# Tab                4172
# iOS and Android    3354
# Laptop             1108
# iOS                 890
# Mobile              600
# Android             304
# Android OS          145
# ANDROID             134
# Other                 2
# Others                2
# Name: count, dtype: int64

# %%
df["preferred_device"]=df["preferred_device"].replace({"Tab":"Mobile","iOS and Android":"Mobile","iOS":"Mobile","Android":"Mobile", "Android OS":"Mobile","ANDROID":"Mobile","Other":"Mobile","Others":"Mobile"})

# %%
df["preferred_device"].value_counts()
# Out:
# preferred_device
# Mobile    9603
# Laptop    1108
# Name: count, dtype: int64

# %%
df["preferred_device"]=df["preferred_device"].replace({"Mobile":0 , "Laptop":1})

# %%
df["preferred_device"].value_counts()
# Out:
# preferred_device
# 0.0    9603
# 1.0    1108
# Name: count, dtype: int64

# %%
df["preferred_device"]=df["preferred_device"].astype("object")

# %%
df['yearly_avg_Outstation_checkins'].value_counts()
# Out:
# yearly_avg_Outstation_checkins
# 1     3907
# 2      844
# 10     627
# 9      340
# 7      336
# 3      336
# 8      320
# 5      261
# 4      256
# 6      236
# 16     231
# 11     208
# 24     203
# 23     200
# 29     198
# 18     189
# 26     188
# 20     183
# 15     182
# 25     180
# 28     164
# 19     161
# 14     152
# 17     145
# 22     143
# 12     141
# 13     139
# 21     133
# 27      85
# *        1
# Name: count, dtype: int64

# %%
df['yearly_avg_Outstation_checkins']=df['yearly_avg_Outstation_checkins'].replace({'*':'1'})

# %%
df['yearly_avg_Outstation_checkins'].value_counts().index
# Out:
# Index(['1', '2', '10', '9', '7', '3', '8', '5', '4', '6', '16', '11', '24',
#        '23', '29', '18', '26', '20', '15', '25', '28', '19', '14', '17', '22',
#        '12', '13', '21', '27'],
#       dtype='object', name='yearly_avg_Outstation_checkins')

# %%
df['yearly_avg_Outstation_checkins']=df['yearly_avg_Outstation_checkins'].astype(float)

# %%
df['member_in_family'].value_counts()
# Out:
# member_in_family
# 3        4160
# 4        2921
# 2        2071
# 1        1231
# 5         355
# Three      15
# 10         11
# Name: count, dtype: int64

# %%
df['member_in_family']=df['member_in_family'].replace({"Three": 3, '10': 5})

# %%
df['member_in_family'].value_counts()
# Out:
# member_in_family
# 3    4160
# 4    2921
# 2    2071
# 1    1231
# 5     355
# 3      15
# 5      11
# Name: count, dtype: int64

# %%
df['member_in_family'] = df['member_in_family'].astype(int)

# %%
df['preferred_location_type'].value_counts()
# Out:
# preferred_location_type
# Beach              2424
# Financial          1996
# Historical site    1856
# Medical            1521
# Big Cities          636
# Other               588
# Trekking            528
# Social media        521
# Entertainment       431
# Hill Stations       108
# Tour  Travel         60
# Tour and Travel      40
# Game                 12
# OTT                   7
# Movie                 5
# Name: count, dtype: int64

# %%
df['preferred_location_type']=df['preferred_location_type'].replace({"Tour  Travel":"Other", "Tour and Travel":"Other", "Game":"Other", "OTT":"Other", "Movie":"Other", "Social media":"Other", "Financial":"Other", "Entertainment":"Other" })

# %%
df['preferred_location_type'].value_counts().index
# Out:
# Index(['Other', 'Beach', 'Historical site', 'Medical', 'Big Cities',
#        'Trekking', 'Hill Stations'],
#       dtype='object', name='preferred_location_type')

# %%
df['preferred_location_type']=df['preferred_location_type'].replace({"Beach": 1, "Historical site": 2, "Medical": 3, "Big Cities": 4, "Trekking": 5, "Hill Stations": 6, "Other": 7})

# %%
df['preferred_location_type'].value_counts()
# Out:
# preferred_location_type
# 7.0    3660
# 1.0    2424
# 2.0    1856
# 3.0    1521
# 4.0     636
# 5.0     528
# 6.0     108
# Name: count, dtype: int64

# %%
df["preferred_location_type"]=df["preferred_location_type"].astype("object")

# %%
df['following_company_page'].value_counts()
# Out:
# following_company_page
# No     7633
# Yes    3011
# 1        12
# 0         5
# Name: count, dtype: int64

# %%
df['following_company_page'] = df['following_company_page'].replace({"Yes": 1, "No": 0})

# %%
df['following_company_page'].value_counts()
# Out:
# following_company_page
# 0    7633
# 1    3011
# 1      12
# 0       5
# Name: count, dtype: int64

# %%
df['working_flag'].value_counts()
# Out:
# working_flag
# No     9107
# Yes    1657
# Name: count, dtype: int64

# %%
df['working_flag']=df['working_flag'].replace({"Yes":1,"No":0})

# %%
df['working_flag'].value_counts()
# Out:
# working_flag
# 0    9107
# 1    1657
# Name: count, dtype: int64

# %%
df['working_flag']=df['working_flag'].astype("object")

# %%
df['Adult_flag'].value_counts()
# Out:
# Adult_flag
# 0    4624
# 1    4361
# 2    1158
# 3     621
# Name: count, dtype: int64

# %%
df['Adult_flag']=df['Adult_flag'].astype("object")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10764 entries, 0 to 11759
# Data columns (total 16 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   Taken_product                                 10764 non-null  object
#  1   Yearly_avg_view_on_travel_page                10283 non-null  float64
#  2   preferred_device                              10711 non-null  object
#  3   total_likes_on_outstation_checkin_given       10444 non-null  float64
#  4   yearly_avg_Outstation_checkins                10689 non-null  float64
#  5   member_in_family                              10764 non-null  int64
#  6   preferred_location_type                       10733 non-null  object
#  7   Yearly_avg_comment_on_travel_page             10558 non-null  float64
#  8   total_likes_on_outofstation_checkin_received  10764 non-null  int64
# ...

# %% [markdown]
# #Checking missing values

# %%
df.isnull().sum().sort_values(ascending=False)
# Out:
# Yearly_avg_view_on_travel_page                  481
# total_likes_on_outstation_checkin_given         320
# Yearly_avg_comment_on_travel_page               206
# following_company_page                          103
# yearly_avg_Outstation_checkins                   75
# preferred_device                                 53
# preferred_location_type                          31
# Taken_product                                     0
# member_in_family                                  0
# total_likes_on_outofstation_checkin_received      0
# week_since_last_outstation_checkin                0
# montly_avg_comment_on_company_page                0
# working_flag                                      0
# travelling_network_rating                         0
# Adult_flag                                        0
# Daily_Avg_mins_spend_on_traveling_page            0
# dtype: int64

# %% [markdown]
# **Imputing the missing values on the categorical variables using their mode**

# %%
df.preferred_device.mode()
# Out:
# 0    0.0
# Name: preferred_device, dtype: object

# %%
df['preferred_device'] = df['preferred_device'].fillna("0.0")

# %%
df.preferred_location_type.mode()
# Out:
# 0    7.0
# Name: preferred_location_type, dtype: object

# %%
df.preferred_location_type = df.preferred_location_type.fillna("7.0")

# %%
df.following_company_page.mode()
# Out:
# 0    0
# Name: following_company_page, dtype: object

# %%
df.following_company_page = df.following_company_page.fillna("0")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10764 entries, 0 to 11759
# Data columns (total 16 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   Taken_product                                 10764 non-null  object
#  1   Yearly_avg_view_on_travel_page                10283 non-null  float64
#  2   preferred_device                              10764 non-null  object
#  3   total_likes_on_outstation_checkin_given       10444 non-null  float64
#  4   yearly_avg_Outstation_checkins                10689 non-null  float64
#  5   member_in_family                              10764 non-null  int64
#  6   preferred_location_type                       10764 non-null  object
#  7   Yearly_avg_comment_on_travel_page             10558 non-null  float64
#  8   total_likes_on_outofstation_checkin_received  10764 non-null  int64
# ...

# %%
df.isnull().sum().sort_values(ascending=False)
# Out:
# Yearly_avg_view_on_travel_page                  481
# total_likes_on_outstation_checkin_given         320
# Yearly_avg_comment_on_travel_page               206
# yearly_avg_Outstation_checkins                   75
# Taken_product                                     0
# preferred_device                                  0
# member_in_family                                  0
# preferred_location_type                           0
# total_likes_on_outofstation_checkin_received      0
# week_since_last_outstation_checkin                0
# following_company_page                            0
# montly_avg_comment_on_company_page                0
# working_flag                                      0
# travelling_network_rating                         0
# Adult_flag                                        0
# Daily_Avg_mins_spend_on_traveling_page            0
# dtype: int64

# %% [markdown]
# **Imputing the missing values on numerical variable by using their mean**

# %%
print("Value count of preferred device: ",df['preferred_device'].value_counts(), "\n""Value count of preferred location type: ",df['preferred_location_type'].value_counts() ,"\n""Value count of following company page: ",df['following_company_page'].value_counts())
# Out:
# Value count of preferred device:  preferred_device
# 0.0    9603
# 1.0    1108
# 0.0      53
# Name: count, dtype: int64
# Value count of preferred location type:  preferred_location_type
# 7.0    3660
# 1.0    2424
# 2.0    1856
# 3.0    1521
# 4.0     636
# 5.0     528
# 6.0     108
# 7.0      31
# Name: count, dtype: int64
# Value count of following company page:  following_company_page
# 0    7633
# 1    3011
# 0     108
# 1      12
# Name: count, dtype: int64

# %%
df['Yearly_avg_view_on_travel_page'].mean()
# Out:
# 281.55411844792377

# %%
df['Yearly_avg_view_on_travel_page'] = df['Yearly_avg_view_on_travel_page'].fillna(281.55)

# %%
df['total_likes_on_outstation_checkin_given'].mean()
# Out:
# 28194.41037916507

# %%
df['total_likes_on_outstation_checkin_given'] = df['total_likes_on_outstation_checkin_given'].fillna(28194.41)

# %%
df['Yearly_avg_comment_on_travel_page'].mean()
# Out:
# 75.68602007956052

# %%
df['Yearly_avg_comment_on_travel_page'] = df['Yearly_avg_comment_on_travel_page'].fillna(75.68)

# %%
df['yearly_avg_Outstation_checkins'].mean()
# Out:
# 8.321264851716718

# %%
df['yearly_avg_Outstation_checkins'] = df['yearly_avg_Outstation_checkins'].fillna(8.32)

# %%
df.isnull().sum().sort_values(ascending=False)
# Out:
# Taken_product                                   0
# Yearly_avg_view_on_travel_page                  0
# preferred_device                                0
# total_likes_on_outstation_checkin_given         0
# yearly_avg_Outstation_checkins                  0
# member_in_family                                0
# preferred_location_type                         0
# Yearly_avg_comment_on_travel_page               0
# total_likes_on_outofstation_checkin_received    0
# week_since_last_outstation_checkin              0
# following_company_page                          0
# montly_avg_comment_on_company_page              0
# working_flag                                    0
# travelling_network_rating                       0
# Adult_flag                                      0
# Daily_Avg_mins_spend_on_traveling_page          0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10764 entries, 0 to 11759
# Data columns (total 16 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   Taken_product                                 10764 non-null  object
#  1   Yearly_avg_view_on_travel_page                10764 non-null  float64
#  2   preferred_device                              10764 non-null  object
#  3   total_likes_on_outstation_checkin_given       10764 non-null  float64
#  4   yearly_avg_Outstation_checkins                10764 non-null  float64
#  5   member_in_family                              10764 non-null  int64
#  6   preferred_location_type                       10764 non-null  object
#  7   Yearly_avg_comment_on_travel_page             10764 non-null  float64
#  8   total_likes_on_outofstation_checkin_received  10764 non-null  int64
# ...

# %%
df.describe().T
# Out:
#                                                 count          mean  \
# Yearly_avg_view_on_travel_page                10764.0    281.553934
# total_likes_on_outstation_checkin_given       10764.0  28194.410368
# yearly_avg_Outstation_checkins                10764.0      8.321256
# member_in_family                              10764.0      2.918246
# Yearly_avg_comment_on_travel_page             10764.0     75.685905
# total_likes_on_outofstation_checkin_received  10764.0   6531.730398
# week_since_last_outstation_checkin            10764.0      3.248792
# montly_avg_comment_on_company_page            10764.0     29.910628
# travelling_network_rating                     10764.0      2.713861
# Daily_Avg_mins_spend_on_traveling_page        10764.0     14.034374
#
#                                                        std     min       25%  \
# Yearly_avg_view_on_travel_page                   66.877485    35.0    233.00
# ...

# %% [markdown]
# #Univariate Analysis

# %%
cat=[]
num=[]
for i in df.columns:
    if df[i].dtype=="object":
        cat.append(i)
    else:
        num.append(i)
print(cat)
print(num)
# Out:
# ['Taken_product', 'preferred_device', 'preferred_location_type', 'following_company_page', 'working_flag', 'Adult_flag']
# ['Yearly_avg_view_on_travel_page', 'total_likes_on_outstation_checkin_given', 'yearly_avg_Outstation_checkins', 'member_in_family', 'Yearly_avg_comment_on_travel_page', 'total_likes_on_outofstation_checkin_received', 'week_since_last_outstation_checkin', 'montly_avg_comment_on_company_page', 'travelling_network_rating', 'Daily_Avg_mins_spend_on_traveling_page']

# %%
sns.boxplot(color = 'violet',data = df, showmeans=True)
plt.show()

# %%
sns.histplot(df['member_in_family'],bins=10);

# %%
sns.histplot(df['total_likes_on_outofstation_checkin_received'],bins=10);

# %%
sns.histplot(df['Yearly_avg_view_on_travel_page'],bins=10);

# %%
sns.histplot(df['total_likes_on_outstation_checkin_given'],bins=10);

# %%
sns.histplot(df['yearly_avg_Outstation_checkins'],bins=10);

# %%
plt.figure(figsize=(9,9))
plt.pie(df["preferred_location_type"].value_counts(),labels=df["preferred_location_type"].value_counts().index,autopct='%1.1f%%')
plt.show()

# %%
sns.pairplot(df)

# %%
data_plot=df[df.dtypes[df.dtypes!='object'].index]
fig=plt.figure(figsize=(12,7))
for i in range(0,len(data_plot.columns)):
   ax=fig.add_subplot(4,3,(i+1))
   sns.boxplot(data_plot[data_plot.columns[i]])
   ax.set_title(data_plot.columns[i],color='Blue')
plt.tight_layout()

# %% [markdown]
# #Bivariate Analysis

# %%
ct = pd.crosstab(df['preferred_location_type'],df['Taken_product'], margins=True )
ct.drop('All',inplace = True)
ct.drop('All',axis = 1,inplace = True)
ct.plot.bar(stacked = True,figsize = (20,7))
plt.show()

# %%
ct = pd.crosstab(df['preferred_device'],df['Taken_product'], margins=True )
ct.drop('All',inplace = True)
ct.drop('All',axis = 1,inplace = True)
ct.plot.bar(stacked = True,figsize = (20,7))
plt.show()

# %%
ct = pd.crosstab(df['week_since_last_outstation_checkin'],df['Taken_product'], margins=True )
ct.drop('All',inplace = True)
ct.drop('All',axis = 1,inplace = True)
ct.plot.bar(stacked = True,figsize = (20,7))
plt.show()

# %%
ct = pd.crosstab(df['Adult_flag'],df['Taken_product'], margins=True )
ct.drop('All',inplace = True)
ct.drop('All',axis = 1,inplace = True)
ct.plot.bar(stacked = True,figsize = (12,5))
plt.show()

# %%
ct = pd.crosstab(df['working_flag'],df['Taken_product'], margins=True )
ct.drop('All',inplace = True)
ct.drop('All',axis = 1,inplace = True)
ct.plot.bar(stacked = True,figsize = (10,5))
plt.show()

# %%
plt.figure(figsize=(15,7))
sns.boxplot(x= 'preferred_location_type', y='total_likes_on_outofstation_checkin_received', data=df)
plt.show()

# %%
sns.boxplot(x="preferred_location_type", y="member_in_family",hue='Taken_product', data=df, orient='h')
# Out:
# <Axes: xlabel='preferred_location_type', ylabel='member_in_family'>

# %%
ct = pd.crosstab(df['preferred_location_type'],df['member_in_family'], margins=True )
ct.drop('All',inplace = True)
ct.drop('All',axis = 1,inplace = True)
ct.plot.bar(stacked = True,figsize = (12,5))
plt.show()

# %%
plt.figure(figsize=(12,5))
sns.stripplot(x=df["Yearly_avg_view_on_travel_page"], y=df['member_in_family'],hue=df['member_in_family'])
plt.show()

# %%
plt.figure(figsize=(12,5))
sns.stripplot(x=df["Taken_product"], y=df['member_in_family'],hue=df['member_in_family'])
plt.show()

# %%
plt.figure(figsize=(20,12))
sns.heatmap(df.corr(),annot=True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-c10a7bf60597> in <cell line: 1>()
# ----> 1 plt.figure(figsize=(20,12))
#       2 sns.heatmap(df.corr(),annot=True)
#       3 plt.show()
#
# NameError: name 'plt' is not defined

# %%
#### get_dummies of the object variables

# %%
print(cat)
# Out:
# ['Taken_product', 'preferred_device', 'preferred_location_type', 'following_company_page', 'working_flag', 'Adult_flag']

# %%
#df =pd.get_dummies(df, columns=cat,drop_first=True)

# %%
#df.head()
# Out:
#    Yearly_avg_view_on_travel_page  total_likes_on_outstation_checkin_given  \
# 0                           307.0                                  38570.0
# 1                           367.0                                   9765.0
# 2                           277.0                                  48055.0
# 3                           247.0                                  48720.0
# 4                           202.0                                  20685.0
#
#    yearly_avg_Outstation_checkins  member_in_family  \
# 0                             1.0                 2
# 1                             1.0                 1
# 2                             1.0                 2
# 3                             1.0                 4
# 4                             1.0                 1
#
#    Yearly_avg_comment_on_travel_page  \
# 0                               94.0
# 1                               61.0
# 2                               92.0
# 3                               56.0
# ...

# %%
cols=['Yearly_avg_view_on_travel_page', 'total_likes_on_outstation_checkin_given', 'yearly_avg_Outstation_checkins', 'member_in_family', 'Yearly_avg_comment_on_travel_page', 'total_likes_on_outofstation_checkin_received', 'week_since_last_outstation_checkin', 'montly_avg_comment_on_company_page', 'travelling_network_rating', 'Daily_Avg_mins_spend_on_traveling_page'];

for i in cols:
    sns.boxplot(df[i])
    plt.show()

# %%
def remove_outlier(col):
    sorted(col)
    Q1,Q3=np.percentile(col,[25,75])
    IQR=Q3-Q1
    lower_range= Q1-(1.5 * IQR)
    upper_range= Q3+(1.5 * IQR)
    return lower_range, upper_range

# %%
for column in df.columns:
    if df[column].dtype != 'object':
         lower_range,upper_range = remove_outlier(df[column])
         df[column]=np.where(df[column]>upper_range,upper_range,df[column])
         df[column]=np.where(df[column]<lower_range,lower_range,df[column])

# %%
for i in cols:
    sns.boxplot(df[i])
    plt.show()

# %%
df['Taken_product'].value_counts()
# Out:
# Taken_product
# 0    9029
# 1    1735
# Name: count, dtype: int64

# %% [markdown]
# #Splitting the Dataset into Laptop and Mobile

# %%
laptop_df = df[df['preferred_device'] == 1]
mobile_df =df[df['preferred_device'] == 0]

# %%
mobile_df.shape
# Out:
# (9603, 16)

# %%
mobile_df.head()
# Out:
#   Taken_product  Yearly_avg_view_on_travel_page preferred_device  \
# 0             1                           307.0              0.0
# 1             0                           367.0              0.0
# 2             1                           277.0              0.0
# 3             0                           247.0              0.0
# 4             0                           202.0              0.0
#
#    total_likes_on_outstation_checkin_given  yearly_avg_Outstation_checkins  \
# 0                                  38570.0                             1.0
# 1                                   9765.0                             1.0
# 2                                  48055.0                             1.0
# 3                                  48720.0                             1.0
# 4                                  20685.0                             1.0
#
#    member_in_family preferred_location_type  \
# 0               2.0                     7.0
# ...

# %%
mobile_df['Taken_product'].value_counts()
# Out:
# Taken_product
# 0    8154
# 1    1449
# Name: count, dtype: int64

# %%
laptop_df.shape
# Out:
# (1108, 16)

# %%
laptop_df.head()
# Out:
#      Taken_product  Yearly_avg_view_on_travel_page preferred_device  \
# 5881             0                           379.0              1.0
# 5883             0                           255.0              1.0
# 5885             0                           250.0              1.0
# 5888             0                           295.0              1.0
# 5906             1                           250.0              1.0
#
#       total_likes_on_outstation_checkin_given  yearly_avg_Outstation_checkins  \
# 5881                                   9776.0                             8.0
# 5883                                  48725.0                             3.0
# 5885                                  35184.0                             2.0
# 5888                                   7572.0                            23.0
# 5906                                  39379.0                            16.0
#
#       member_in_family preferred_location_type  \
# ...

# %%
laptop_df['Taken_product'].value_counts()
# Out:
# Taken_product
# 0    832
# 1    276
# Name: count, dtype: int64

# %% [markdown]
# #Scaling the Datasets

# %%
cat1=[]
num1=[]
for i in mobile_df.columns:
    if mobile_df[i].dtype=="object":
        cat1.append(i)
    else:
        num1.append(i)
print(cat1)
print(num1)
# Out:
# ['Taken_product', 'preferred_device', 'preferred_location_type', 'following_company_page', 'working_flag', 'Adult_flag']
# ['Yearly_avg_view_on_travel_page', 'total_likes_on_outstation_checkin_given', 'yearly_avg_Outstation_checkins', 'member_in_family', 'Yearly_avg_comment_on_travel_page', 'total_likes_on_outofstation_checkin_received', 'week_since_last_outstation_checkin', 'montly_avg_comment_on_company_page', 'travelling_network_rating', 'Daily_Avg_mins_spend_on_traveling_page']

# %%
mobile_df =pd.get_dummies(mobile_df, columns=cat1,drop_first=True)

# %%
mobile_df.head()
# Out:
#    Yearly_avg_view_on_travel_page  total_likes_on_outstation_checkin_given  \
# 0                           307.0                                  38570.0
# 1                           367.0                                   9765.0
# 2                           277.0                                  48055.0
# 3                           247.0                                  48720.0
# 4                           202.0                                  20685.0
#
#    yearly_avg_Outstation_checkins  member_in_family  \
# 0                             1.0               2.0
# 1                             1.0               1.0
# 2                             1.0               2.0
# 3                             1.0               4.0
# 4                             1.0               1.0
#
#    Yearly_avg_comment_on_travel_page  \
# 0                               94.0
# 1                               61.0
# 2                               92.0
# 3                               56.0
# ...

# %%
mobile_df['Taken_product_1'].value_counts()
# Out:
# Taken_product_1
# False    8154
# True     1449
# Name: count, dtype: int64

# %%
mobile_df[num1] = mobile_df[num1].apply(lambda x:(x-x.min()) / (x.max()-x.min()))

# %%
mobile_df.head()
# Out:
#    Yearly_avg_view_on_travel_page  total_likes_on_outstation_checkin_given  \
# 0                        0.582865                                 0.487250
# 1                        0.751404                                 0.086243
# 2                        0.498596                                 0.619294
# 3                        0.414326                                 0.628552
# 4                        0.287921                                 0.238265
#
#    yearly_avg_Outstation_checkins  member_in_family  \
# 0                             0.0              0.25
# 1                             0.0              0.00
# 2                             0.0              0.25
# 3                             0.0              0.75
# 4                             0.0              0.00
#
#    Yearly_avg_comment_on_travel_page  \
# 0                           0.632143
# 1                           0.396429
# 2                           0.617857
# 3                           0.360714
# ...

# %%
cat2=[]
num2=[]
for i in laptop_df.columns:
    if laptop_df[i].dtype=="object":
        cat2.append(i)
    else:
        num2.append(i)
print(cat2)
print(num2)
# Out:
# ['Taken_product', 'preferred_device', 'preferred_location_type', 'following_company_page', 'working_flag', 'Adult_flag']
# ['Yearly_avg_view_on_travel_page', 'total_likes_on_outstation_checkin_given', 'yearly_avg_Outstation_checkins', 'member_in_family', 'Yearly_avg_comment_on_travel_page', 'total_likes_on_outofstation_checkin_received', 'week_since_last_outstation_checkin', 'montly_avg_comment_on_company_page', 'travelling_network_rating', 'Daily_Avg_mins_spend_on_traveling_page']

# %%
laptop_df =pd.get_dummies(laptop_df, columns=cat2,drop_first=True)

# %%
laptop_df.head()
# Out:
#       Yearly_avg_view_on_travel_page  total_likes_on_outstation_checkin_given  \
# 5881                           379.0                                   9776.0
# 5883                           255.0                                  48725.0
# 5885                           250.0                                  35184.0
# 5888                           295.0                                   7572.0
# 5906                           250.0                                  39379.0
#
#       yearly_avg_Outstation_checkins  member_in_family  \
# 5881                             8.0               1.0
# 5883                             3.0               4.0
# 5885                             2.0               2.0
# 5888                            23.0               3.0
# 5906                            16.0               1.0
#
#       Yearly_avg_comment_on_travel_page  \
# 5881                               64.0
# 5883                               59.0
# ...

# %%
laptop_df['Taken_product_1'].value_counts()
# Out:
# Taken_product_1
# False    832
# True     276
# Name: count, dtype: int64

# %%
laptop_df[num2] = laptop_df[num2].apply(lambda x:(x-x.min()) / (x.max()-x.min()))

# %%
laptop_df.head()
# Out:
#       Yearly_avg_view_on_travel_page  total_likes_on_outstation_checkin_given  \
# 5881                        0.759055                                 0.122356
# 5883                        0.368504                                 0.922229
# 5885                        0.352756                                 0.644145
# 5888                        0.494488                                 0.077094
# 5906                        0.352756                                 0.730295
#
#       yearly_avg_Outstation_checkins  member_in_family  \
# 5881                        0.250000              0.00
# 5883                        0.071429              0.75
# 5885                        0.035714              0.25
# 5888                        0.785714              0.50
# 5906                        0.535714              0.00
#
#       Yearly_avg_comment_on_travel_page  \
# 5881                           0.336957
# 5883                           0.282609
# ...

# %% [markdown]
# #Split the Dataset into Train and Test

# %%
# Copy all the predictor variables into X1 dataframe
X1 = mobile_df.drop('Taken_product_1', axis=1)

# Copy target into the y1 dataframe.
y1 = mobile_df['Taken_product_1']

# %%
# Copy all the predictor variables into X2 dataframe
X2 = laptop_df.drop('Taken_product_1', axis=1)

# Copy target into the y2 dataframe.
y2 = laptop_df['Taken_product_1']

# %%
X1.head()
# Out:
#    Yearly_avg_view_on_travel_page  total_likes_on_outstation_checkin_given  \
# 0                        0.582865                                 0.487250
# 1                        0.751404                                 0.086243
# 2                        0.498596                                 0.619294
# 3                        0.414326                                 0.628552
# 4                        0.287921                                 0.238265
#
#    yearly_avg_Outstation_checkins  member_in_family  \
# 0                             0.0              0.25
# 1                             0.0              0.00
# 2                             0.0              0.25
# 3                             0.0              0.75
# 4                             0.0              0.00
#
#    Yearly_avg_comment_on_travel_page  \
# 0                           0.632143
# 1                           0.396429
# 2                           0.617857
# 3                           0.360714
# ...

# %%
X2.head()
# Out:
#       Yearly_avg_view_on_travel_page  total_likes_on_outstation_checkin_given  \
# 5881                        0.759055                                 0.122356
# 5883                        0.368504                                 0.922229
# 5885                        0.352756                                 0.644145
# 5888                        0.494488                                 0.077094
# 5906                        0.352756                                 0.730295
#
#       yearly_avg_Outstation_checkins  member_in_family  \
# 5881                        0.250000              0.00
# 5883                        0.071429              0.75
# 5885                        0.035714              0.25
# 5888                        0.785714              0.50
# 5906                        0.535714              0.00
#
#       Yearly_avg_comment_on_travel_page  \
# 5881                           0.336957
# 5883                           0.282609
# ...

# %%
y1.head()
# Out:
# 0     True
# 1    False
# 2     True
# 3    False
# 4    False
# Name: Taken_product_1, dtype: bool

# %%
y2.head()
# Out:
# 5881    False
# 5883    False
# 5885    False
# 5888    False
# 5906     True
# Name: Taken_product_1, dtype: bool

# %%
# Split X1 and y1 into training and test set in 70:30 ratio
from sklearn.model_selection import train_test_split
X1_train, X1_test, y1_train, y1_test = train_test_split(X1, y1, test_size=0.30 , random_state=1)

# %%
# Split X2 and y2 into training and test set in 70:30 ratio

X2_train, X2_test, y2_train, y2_test = train_test_split(X2, y2, test_size=0.30 , random_state=1)

# %% [markdown]
# #Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
Log_model= LogisticRegression()
Log_model.fit(X1_train, y1_train)
# Out:
# LogisticRegression()

# %%
## Performance Matrix on train data set for Mobile
y1_train_predict2 = Log_model.predict(X1_train)
model_score = Log_model.score(X1_train, y1_train)
print(model_score)
print(metrics.confusion_matrix(y1_train, y1_train_predict2))
print(metrics.classification_report(y1_train, y1_train_predict2))
# Out:
# 0.8678964593870871
# [[5574  108]
#  [ 780  260]]
#               precision    recall  f1-score   support
#
#        False       0.88      0.98      0.93      5682
#         True       0.71      0.25      0.37      1040
#
#     accuracy                           0.87      6722
#    macro avg       0.79      0.62      0.65      6722
# weighted avg       0.85      0.87      0.84      6722

# %%
## Performance Matrix on test data set for Mobile
y1_test_predict2 = Log_model.predict(X1_test)
model_score = Log_model.score(X1_test, y1_test)
print(model_score)
print(metrics.confusion_matrix(y1_test, y1_test_predict2))
print(metrics.classification_report(y1_test, y1_test_predict2))
# Out:
# 0.8722665741062131
# [[2428   44]
#  [ 324   85]]
#               precision    recall  f1-score   support
#
#        False       0.88      0.98      0.93      2472
#         True       0.66      0.21      0.32       409
#
#     accuracy                           0.87      2881
#    macro avg       0.77      0.60      0.62      2881
# weighted avg       0.85      0.87      0.84      2881

# %%
Log_model2= LogisticRegression()
Log_model2.fit(X2_train, y2_train)
# Out:
# LogisticRegression()

# %%
## Performance Matrix on train data set for Laptop
y2_train_predict = Log_model2.predict(X2_train)
model_score = Log_model2.score(X2_train, y2_train)
print(model_score)
print(metrics.confusion_matrix(y2_train, y2_train_predict))
print(metrics.classification_report(y2_train, y2_train_predict))
# Out:
# 0.8335483870967741
# [[569  25]
#  [104  77]]
#               precision    recall  f1-score   support
#
#        False       0.85      0.96      0.90       594
#         True       0.75      0.43      0.54       181
#
#     accuracy                           0.83       775
#    macro avg       0.80      0.69      0.72       775
# weighted avg       0.82      0.83      0.82       775

# %%
## Performance Matrix on test data set for Laptop
y2_test_predict = Log_model2.predict(X2_test)
model_score = Log_model2.score(X2_test, y2_test)
print(model_score)
print(metrics.confusion_matrix(y2_test, y2_test_predict))
print(metrics.classification_report(y2_test, y2_test_predict))
# Out:
# 0.8078078078078078
# [[225  13]
#  [ 51  44]]
#               precision    recall  f1-score   support
#
#        False       0.82      0.95      0.88       238
#         True       0.77      0.46      0.58        95
#
#     accuracy                           0.81       333
#    macro avg       0.79      0.70      0.73       333
# weighted avg       0.80      0.81      0.79       333

# %% [markdown]
# #ADA Boost

# %%
from sklearn.ensemble import AdaBoostClassifier


ADB_model = AdaBoostClassifier(n_estimators=100,random_state=1)
ADB_model.fit(X1_train,y1_train)
# Out:
# AdaBoostClassifier(n_estimators=100, random_state=1)

# %%
## Performance Matrix on train data set for Mobile
y1_train_predict_ada = ADB_model.predict(X1_train)
model_score = ADB_model.score(X1_train, y1_train)
print(model_score)
print(metrics.confusion_matrix(y1_train, y1_train_predict_ada))
print(metrics.classification_report(y1_train, y1_train_predict_ada))
# Out:
# 0.881136566498066
# [[5541  141]
#  [ 658  382]]
#               precision    recall  f1-score   support
#
#        False       0.89      0.98      0.93      5682
#         True       0.73      0.37      0.49      1040
#
#     accuracy                           0.88      6722
#    macro avg       0.81      0.67      0.71      6722
# weighted avg       0.87      0.88      0.86      6722

# %%
## Performance Matrix on test data set for Mobile
y1_test_predict_ada = ADB_model.predict(X1_test)
model_score = ADB_model.score(X1_test, y1_test)
print(model_score)
print(metrics.confusion_matrix(y1_test, y1_test_predict_ada))
print(metrics.classification_report(y1_test, y1_test_predict_ada))
# Out:
# 0.8771259979173898
# [[2406   66]
#  [ 288  121]]
#               precision    recall  f1-score   support
#
#        False       0.89      0.97      0.93      2472
#         True       0.65      0.30      0.41       409
#
#     accuracy                           0.88      2881
#    macro avg       0.77      0.63      0.67      2881
# weighted avg       0.86      0.88      0.86      2881

# %%
ADB_model2 = AdaBoostClassifier(n_estimators=100,random_state=1)
ADB_model2.fit(X2_train,y2_train)
# Out:
# AdaBoostClassifier(n_estimators=100, random_state=1)

# %%
## Performance Matrix on train data set for Laptop
y2_train_predict_ada = ADB_model2.predict(X2_train)
model_score = ADB_model2.score(X2_train, y2_train)
print(model_score)
print(metrics.confusion_matrix(y2_train, y2_train_predict_ada))
print(metrics.classification_report(y2_train, y2_train_predict_ada))
# Out:
# 0.9458064516129032
# [[588   6]
#  [ 36 145]]
#               precision    recall  f1-score   support
#
#        False       0.94      0.99      0.97       594
#         True       0.96      0.80      0.87       181
#
#     accuracy                           0.95       775
#    macro avg       0.95      0.90      0.92       775
# weighted avg       0.95      0.95      0.94       775

# %%
## Performance Matrix on test data set for Laptop
y2_test_predict_ada = ADB_model2.predict(X2_test)
model_score = ADB_model2.score(X2_test, y2_test)
print(model_score)
print(metrics.confusion_matrix(y2_test, y2_test_predict_ada))
print(metrics.classification_report(y2_test, y2_test_predict_ada))
# Out:
# 0.8768768768768769
# [[225  13]
#  [ 28  67]]
#               precision    recall  f1-score   support
#
#        False       0.89      0.95      0.92       238
#         True       0.84      0.71      0.77        95
#
#     accuracy                           0.88       333
#    macro avg       0.86      0.83      0.84       333
# weighted avg       0.87      0.88      0.87       333

# %% [markdown]
# #KNN Model

# %%
from sklearn.neighbors import KNeighborsClassifier

KNN_model=KNeighborsClassifier()
KNN_model.fit(X1_train,y1_train)
# Out:
# KNeighborsClassifier()

# %%
## Performance Matrix on train data set for Mobile
y1_train_predict_knn = KNN_model.predict(X1_train)
model_score = KNN_model.score(X1_train, y1_train)
print(model_score)
print(metrics.confusion_matrix(y1_train, y1_train_predict_knn))
print(metrics.classification_report(y1_train, y1_train_predict_knn))
# Out:
# 0.9494198155310919
# [[5593   89]
#  [ 251  789]]
#               precision    recall  f1-score   support
#
#        False       0.96      0.98      0.97      5682
#         True       0.90      0.76      0.82      1040
#
#     accuracy                           0.95      6722
#    macro avg       0.93      0.87      0.90      6722
# weighted avg       0.95      0.95      0.95      6722

# %%
## Performance Matrix on test data set for Mobile
y1_test_predict_knn = KNN_model.predict(X1_test)
model_score = KNN_model.score(X1_test, y1_test)
print(model_score)
print(metrics.confusion_matrix(y1_test, y1_test_predict_knn))
print(metrics.classification_report(y1_test, y1_test_predict_knn))
# Out:
# 0.8976049982644915
# [[2379   93]
#  [ 202  207]]
#               precision    recall  f1-score   support
#
#        False       0.92      0.96      0.94      2472
#         True       0.69      0.51      0.58       409
#
#     accuracy                           0.90      2881
#    macro avg       0.81      0.73      0.76      2881
# weighted avg       0.89      0.90      0.89      2881

# %%
KNN_model2 =KNeighborsClassifier()
KNN_model2.fit(X2_train,y2_train)
# Out:
# KNeighborsClassifier()

# %%
## Performance Matrix on train data set
y2_train_predict_knn = KNN_model2.predict(X2_train)
model_score = KNN_model2.score(X2_train, y2_train)
print(model_score)
print(metrics.confusion_matrix(y2_train, y2_train_predict_knn))
print(metrics.classification_report(y2_train, y2_train_predict_knn))
# Out:
# 0.96
# [[587   7]
#  [ 24 157]]
#               precision    recall  f1-score   support
#
#        False       0.96      0.99      0.97       594
#         True       0.96      0.87      0.91       181
#
#     accuracy                           0.96       775
#    macro avg       0.96      0.93      0.94       775
# weighted avg       0.96      0.96      0.96       775

# %%
## Performance Matrix on test data set for laptop
y2_test_predict_knn = KNN_model2.predict(X2_test)
model_score = KNN_model2.score(X2_test, y2_test)
print(model_score)
print(metrics.confusion_matrix(y2_test, y2_test_predict_knn))
print(metrics.classification_report(y2_test, y2_test_predict_knn))
# Out:
# 0.8648648648648649
# [[230   8]
#  [ 37  58]]
#               precision    recall  f1-score   support
#
#        False       0.86      0.97      0.91       238
#         True       0.88      0.61      0.72        95
#
#     accuracy                           0.86       333
#    macro avg       0.87      0.79      0.82       333
# weighted avg       0.87      0.86      0.86       333

# %% [markdown]
# #Decision Tree

# %%
from sklearn import tree


DT_model= tree.DecisionTreeClassifier()
DT_model.fit(X1_train, y1_train)
# Out:
# DecisionTreeClassifier()

# %%
## Performance Matrix on train data set for Mobile
y1_train_predict_dt = DT_model.predict(X1_train)
model_score = DT_model.score(X1_train, y1_train)
print(model_score)
print(metrics.confusion_matrix(y1_train, y1_train_predict_dt))
print(metrics.classification_report(y1_train, y1_train_predict_dt))
# Out:
# 1.0
# [[5682    0]
#  [   0 1040]]
#               precision    recall  f1-score   support
#
#        False       1.00      1.00      1.00      5682
#         True       1.00      1.00      1.00      1040
#
#     accuracy                           1.00      6722
#    macro avg       1.00      1.00      1.00      6722
# weighted avg       1.00      1.00      1.00      6722

# %%
## Performance Matrix on test data set for Mobile
y1_test_predict_dt = DT_model.predict(X1_test)
model_score = DT_model.score(X1_test, y1_test)
print(model_score)
print(metrics.confusion_matrix(y1_test, y1_test_predict_dt))
print(metrics.classification_report(y1_test, y1_test_predict_dt))
# Out:
# 0.9500173550850399
# [[2393   79]
#  [  65  344]]
#               precision    recall  f1-score   support
#
#        False       0.97      0.97      0.97      2472
#         True       0.81      0.84      0.83       409
#
#     accuracy                           0.95      2881
#    macro avg       0.89      0.90      0.90      2881
# weighted avg       0.95      0.95      0.95      2881

# %%
DT_model2= tree.DecisionTreeClassifier()
DT_model2.fit(X2_train, y2_train)
# Out:
# DecisionTreeClassifier()

# %%
## Performance Matrix on train data set for Laptop
y2_train_predict_dt = DT_model2.predict(X2_train)
model_score = DT_model2.score(X2_train, y2_train)
print(model_score)
print(metrics.confusion_matrix(y2_train, y2_train_predict_dt))
print(metrics.classification_report(y2_train, y2_train_predict_dt))
# Out:
# 1.0
# [[594   0]
#  [  0 181]]
#               precision    recall  f1-score   support
#
#        False       1.00      1.00      1.00       594
#         True       1.00      1.00      1.00       181
#
#     accuracy                           1.00       775
#    macro avg       1.00      1.00      1.00       775
# weighted avg       1.00      1.00      1.00       775

# %%
## Performance Matrix on test data set
y2_test_predict_dt = DT_model2.predict(X2_test)
model_score = DT_model2.score(X2_test, y2_test)
print(model_score)
print(metrics.confusion_matrix(y2_test, y2_test_predict_dt))
print(metrics.classification_report(y2_test, y2_test_predict_dt))
# Out:
# 0.9519519519519519
# [[235   3]
#  [ 13  82]]
#               precision    recall  f1-score   support
#
#        False       0.95      0.99      0.97       238
#         True       0.96      0.86      0.91        95
#
#     accuracy                           0.95       333
#    macro avg       0.96      0.93      0.94       333
# weighted avg       0.95      0.95      0.95       333

# %% [markdown]
# #Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier

RF_model=RandomForestClassifier(n_estimators=100,random_state=1)
RF_model.fit(X1_train, y1_train)
# Out:
# RandomForestClassifier(random_state=1)

# %%
## Performance Matrix on train data  for Mobile
y1_train_predict_rf = RF_model.predict(X1_train)
model_score =RF_model.score(X1_train, y1_train)
print(model_score)
print(metrics.confusion_matrix(y1_train, y1_train_predict_rf))
print(metrics.classification_report(y1_train, y1_train_predict_rf))
# Out:
# 1.0
# [[5682    0]
#  [   0 1040]]
#               precision    recall  f1-score   support
#
#        False       1.00      1.00      1.00      5682
#         True       1.00      1.00      1.00      1040
#
#     accuracy                           1.00      6722
#    macro avg       1.00      1.00      1.00      6722
# weighted avg       1.00      1.00      1.00      6722

# %%
## Performance Matrix on test data set for Mobile
y1_test_predict_rf = RF_model.predict(X1_test)
model_score = RF_model.score(X1_test, y1_test)
print(model_score)
print(metrics.confusion_matrix(y1_test, y1_test_predict_rf))
print(metrics.classification_report(y1_test, y1_test_predict_rf))
# Out:
# 0.9663311350225616
# [[2472    0]
#  [  97  312]]
#               precision    recall  f1-score   support
#
#        False       0.96      1.00      0.98      2472
#         True       1.00      0.76      0.87       409
#
#     accuracy                           0.97      2881
#    macro avg       0.98      0.88      0.92      2881
# weighted avg       0.97      0.97      0.96      2881

# %%
feature_importances =RF_model.feature_importances_
features = X1.columns

# %%
importance_df = pd.DataFrame({
    'Feature': features,
    'Importance': feature_importances
}).sort_values(by='Importance', ascending=False)

print(importance_df)
# Out:
#                                          Feature  Importance
# 5   total_likes_on_outofstation_checkin_received    0.156089
# 1        total_likes_on_outstation_checkin_given    0.120676
# 0                 Yearly_avg_view_on_travel_page    0.117693
# 9         Daily_Avg_mins_spend_on_traveling_page    0.076375
# 2                 yearly_avg_Outstation_checkins    0.076123
# 4              Yearly_avg_comment_on_travel_page    0.073402
# 17                      following_company_page_1    0.069096
# 6             week_since_last_outstation_checkin    0.060041
# 7             montly_avg_comment_on_company_page    0.048547
# 3                               member_in_family    0.046738
# 8                      travelling_network_rating    0.045850
# 21                                  Adult_flag_1    0.029022
# 22                                  Adult_flag_2    0.012920
# 20                                working_flag_1    0.011516
# ...

# %%
RF_model2=RandomForestClassifier(n_estimators=100,random_state=1)
RF_model2.fit(X2_train, y2_train)
# Out:
# RandomForestClassifier(random_state=1)

# %%
## Performance Matrix on train data set for Laptop
y2_train_predict_rf = RF_model2.predict(X2_train)
model_score =RF_model2.score(X2_train, y2_train)
print(model_score)
print(metrics.confusion_matrix(y2_train, y2_train_predict_rf))
print(metrics.classification_report(y2_train, y2_train_predict_rf))
# Out:
# 1.0
# [[594   0]
#  [  0 181]]
#               precision    recall  f1-score   support
#
#        False       1.00      1.00      1.00       594
#         True       1.00      1.00      1.00       181
#
#     accuracy                           1.00       775
#    macro avg       1.00      1.00      1.00       775
# weighted avg       1.00      1.00      1.00       775

# %%
## Performance Matrix on test data set
y2_test_predict_rf = RF_model2.predict(X2_test)
model_score = RF_model2.score(X2_test, y2_test)
print(model_score)
print(metrics.confusion_matrix(y2_test, y2_test_predict_rf))
print(metrics.classification_report(y2_test, y2_test_predict_rf))
# Out:
# 0.975975975975976
# [[238   0]
#  [  8  87]]
#               precision    recall  f1-score   support
#
#        False       0.97      1.00      0.98       238
#         True       1.00      0.92      0.96        95
#
#     accuracy                           0.98       333
#    macro avg       0.98      0.96      0.97       333
# weighted avg       0.98      0.98      0.98       333

# %%
feature_importances2 =RF_model2.feature_importances_
features = X2.columns

# %%
importance_df2 = pd.DataFrame({
    'Feature': features,
    'Importance': feature_importances2
}).sort_values(by='Importance', ascending=False)

print(importance_df2)
# Out:
#                                          Feature  Importance
# 0                 Yearly_avg_view_on_travel_page    0.163656
# 5   total_likes_on_outofstation_checkin_received    0.159646
# 1        total_likes_on_outstation_checkin_given    0.116622
# 2                 yearly_avg_Outstation_checkins    0.090027
# 4              Yearly_avg_comment_on_travel_page    0.070164
# 9         Daily_Avg_mins_spend_on_traveling_page    0.069064
# 15                      following_company_page_1    0.056350
# 7             montly_avg_comment_on_company_page    0.046942
# 6             week_since_last_outstation_checkin    0.044147
# 8                      travelling_network_rating    0.042271
# 3                               member_in_family    0.034345
# 10                   preferred_location_type_2.0    0.021992
# 17                                  Adult_flag_1    0.020354
# 18                                  Adult_flag_2    0.011681
# ...

# %% [markdown]
# #Comparison of different models for Mobile

# %% [markdown]
# **Logistic regression**
#
# * Recall value - 0.21
# * Accuracy - 0.87
# *  Precision - 0.66
#
# **ADA Boost**
#
# * Recall value - 0.30
# * Accuracy - 0.88
# *  Precision - 0.65
#
# **KNN Model**
#
#
# * Recall value - 0.51
# * Accuracy - 0.90
# *  Precision - 0.69
#
#
# **Decision Tree**
#
#
# * Recall value - 0.84
# * Accuracy - 0.95
# *  Precision - 0.81
#
#
# **Random Forest**
#
#
# * Recall value - 0.76
# * Accuracy - 0.97
# *  Precision - 1.00

# %% [markdown]
# #Comparison of different models for Laptop

# %% [markdown]
# **Logistic regression**
#
# * Recall value - 0.46
# * Accuracy - 0.81
# *  Precision - 0.77
#
# **ADA Boost**
#
# * Recall value - 0.71
# * Accuracy - 0.88
# *  Precision - 0.84
#
# **KNN Model**
#
#
# * Recall value - 0.61
# * Accuracy - 0.86
# *  Precision - 0.88
#
#
# **Decision Tree**
#
#
# * Recall value - 0.86
# * Accuracy - 0.95
# *  Precision - 0.96
#
#
# **Random Forest**
#
#
# * Recall value - 0.92
# * Accuracy - 0.98
# *  Precision - 1.00

# %% [markdown]
# we see overfitting in case of random forest and decision tree  for both Laptop and Mobile

# %% [markdown]
# #SMOTE

# %%
from imblearn.over_sampling import SMOTE

# %%
sm = SMOTE(random_state=2)
X1_train_res, y1_train_res = sm.fit_resample(X1_train, y1_train.ravel())

# %%
sm2 = SMOTE(random_state=2)
X2_train_res, y2_train_res = sm2.fit_resample(X2_train, y2_train.ravel())

# %%
## Let's check the shape after SMOTE
X1_train_res.shape

# %%
## Let's check the shape after SMOTE
X2_train_res.shape

# %% [markdown]
# #Decision Tree With SMOTE

# %%
DT_model_sm= tree.DecisionTreeClassifier()
DT_model_sm.fit(X1_train_res, y1_train_res)

# %%
## Performance Matrix on train data set for Mobile after SMOTE
y1_train_smote = DT_model_sm.predict(X1_train_res)
model_score = DT_model_sm.score(X1_train_res, y1_train_res)
print(model_score)
print(metrics.confusion_matrix(y1_train_res, y1_train_smote))
print(metrics.classification_report(y1_train_res, y1_train_smote))

# %%
## Performance Matrix on test data set for Mobile after SMOTE
y1_test_smote = DT_model_sm.predict(X1_test)
model_score = DT_model_sm.score(X1_test, y1_test)
print(model_score)
print(metrics.confusion_matrix(y1_test, y1_test_smote))
print(metrics.classification_report(y1_test, y1_test_smote))

# %%
DT_model2_sm= tree.DecisionTreeClassifier()
DT_model2_sm.fit(X2_train_res, y2_train_res)

# %%
## Performance Matrix on train data set for Laptop after SMOTE
y2_train_smote = DT_model2_sm.predict(X2_train_res)
model_score = DT_model2_sm.score(X2_train_res, y2_train_res)
print(model_score)
print(metrics.confusion_matrix(y2_train_res, y2_train_smote))
print(metrics.classification_report(y2_train_res, y2_train_smote))

# %%
## Performance Matrix on test data set for Laptop after SMOTE
y2_test_smote = DT_model2_sm.predict(X2_test)
model_score = DT_model2_sm.score(X2_test, y2_test)
print(model_score)
print(metrics.confusion_matrix(y2_test, y2_test_smote))
print(metrics.classification_report(y2_test, y2_test_smote))

# %% [markdown]
# After applying smote on DT we see that the recall value on test dataset decreases from 84% to 81% for Mobile while the recall value increases from 83% to 94% on the Laptop dataset.
#
# Hence , SMOTE is useful for Laptop dataset but not Mobile dataset.

# %% [markdown]
# #Random Forest with SMOTE

# %%
RF_model_sm=RandomForestClassifier(n_estimators=100,random_state=1)
RF_model_sm.fit(X1_train_res, y1_train_res)

# %%
## Performance Matrix on train data  for Mobile After SMOTE
y1_train_rf_smote = RF_model_sm.predict(X1_train_res)
model_score =RF_model_sm.score(X1_train_res, y1_train_res)
print(model_score)
print(metrics.confusion_matrix(y1_train_res, y1_train_rf_smote))
print(metrics.classification_report(y1_train_res, y1_train_rf_smote))

# %%
## Performance Matrix on test data set for Mobile
y1_test_rf_smote = RF_model_sm.predict(X1_test)
model_score = RF_model_sm.score(X1_test, y1_test)
print(model_score)
print(metrics.confusion_matrix(y1_test, y1_test_rf_smote))
print(metrics.classification_report(y1_test, y1_test_rf_smote))

# %%
RF_model2_sm=RandomForestClassifier(n_estimators=100,random_state=1)
RF_model2_sm.fit(X2_train_res, y2_train_res)

# %%
## Performance Matrix on train data set for Laptop
y2_train_rf_smote = RF_model2_sm.predict(X2_train_res)
model_score =RF_model2_sm.score(X2_train_res, y2_train_res)
print(model_score)
print(metrics.confusion_matrix(y2_train_res, y2_train_rf_smote))
print(metrics.classification_report(y2_train_res, y2_train_rf_smote))

# %%
## Performance Matrix on test data set
y2_test_rf_smote = RF_model2_sm.predict(X2_test)
model_score = RF_model2_sm.score(X2_test, y2_test)
print(model_score)
print(metrics.confusion_matrix(y2_test, y2_test_rf_smote))
print(metrics.classification_report(y2_test, y2_test_rf_smote))

# %% [markdown]
# 76% to 89% on mobile dataset after applying SMOTE and 92% to 94% on LAptop
